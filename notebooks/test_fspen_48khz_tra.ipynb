# %%
import pyroomacoustics as pra

import os
from tqdm import tqdm

import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from torch.autograd import profiler
import torchaudio
from torchmetrics.audio import SpeechReverberationModulationEnergyRatio, ShortTimeObjectiveIntelligibility, DeepNoiseSuppressionMeanOpinionScore


from einops import rearrange

from src.dataset import SignalDataset, TRUNetDataset
from src.loss import loss_tot, loss_MR, loss_MR_w
from models.fspen import * # FullSubPathExtension, FullSubPathExtension_3_heads, FullSubPathExtension_ver2, FullSubPathExtension_abs_pha, FullSubPathExtension_abs_pha_mapping, FullSubPathExtension_ver2_abs_pha, FullSubPathExtension_ver3

from IPython.display import Audio

from src.utils import model_eval, model_eval_fspen2x_ver3, model_eval_3_heads, use_pcs, inv_pcs, model_eval_old

import random

from torch_pesq import PesqLoss

import matplotlib.pyplot as plt

# %%
TEST_DIR = os.path.join("data", "DS_10283_2791", "clean_testset_wav")
TEST_NOISE_DIR = os.path.join("data", "DS_10283_2791", "noisy_testset_wav")
NOISE_DIR = os.path.join("data", "demand_test")

CHKP_DIR = "checkpoints"

np.set_printoptions(precision=3)
torch.set_printoptions(precision=3)

# %%
SEED = 1984

np.random.seed(SEED)
torch.manual_seed(SEED)
random.seed(SEED)

# %%
from src.fspen_configs import *

configs = TrainConfig_48khz()
# print(sum(configs.bands_num_in_groups), configs.dual_path_extension["num_modules"])
fspen = FullSubPathExtensionTRA_ver2(configs=configs)# .to(DEVICE)

state_d = torch.load(os.path.join(CHKP_DIR, "fspen_chkp", "TrainConfig_48khz_baseline_TRA_ver2#0.pt"), map_location="cpu",  weights_only=False)
# Out:
# 64

# %%
fspen.load_state_dict(state_d["model_state_dict"])
# Out:
# <All keys matched successfully>

# %%
# N_FFTS = 512
# HOP_LENGTH = 256
# HID_SIZE = 32
# SR = 16_000

N_FFTS = configs.n_fft
HOP_LENGTH = configs.hop_length
HID_SIZE = 64
SR = configs.sample_rate
BATCH_SIZE = 8 # 32

DEVICE = "cpu" # torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"It's {DEVICE} time!!!")
# Out:
# It's cpu time!!!

# %%
rir_dict = {1: os.path.join("data", "rirs48_small_3_test"), 1: os.path.join("data", "rirs48_medium_3_test"), 1: os.path.join("data", "rirs48_large_3_test"), 1: os.path.join("data", "rirs48_super_large_3_test")}
dataset = TRUNetDataset(TEST_DIR, sr=SR, noise_dir=NOISE_DIR, rir_dir=rir_dict, snr=[0, 5, 10, 15], rir_proba=0.85, noise_proba=0.85, rir_target=False, return_noise=False, return_rir=False)
dataset.set_epoch(99)
# Out:
# 180
# 12

# %%
def vorbis_window(winlen, device="cuda"):
    sq = torch.sin(torch.pi/2*(torch.sin(torch.pi/winlen*(torch.arange(winlen)-0.5))**2)).float()
    return sq

# %%
import yaml

from NISQA_s.src.core.model_torch import model_init
from NISQA_s.src.utils.process_utils import process

NISQA_PATH = "NISQA_s/config/nisqa_s.yaml"

with open(NISQA_PATH, 'r') as stream:
    nisqa_args = yaml.safe_load(stream)
nisqa_args["ms_n_fft"] = 512
nisqa_args["hop_length"] = 256
nisqa_args["ms_win_length"] = 512
nisqa_args["ckp"] = nisqa_args["ckp"][3:]

nisqa, h0_nisqa, c0_nisqa = model_init(nisqa_args)
# Out:
# /home/zakhar/miniconda3/envs/ems_dereverb/lib/python3.10/site-packages/torch/nn/modules/rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
def pad_sequence(batch):
    if not batch:
        return torch.zeros(0), torch.zeros(0)

    input_signal, target_signal, noise, rir = zip(*batch)
        
    max_len_s = max(s.shape[-1] for s in input_signal)
    
    padded_input = torch.zeros(len(input_signal), max_len_s)
    padded_target = torch.zeros(len(target_signal), max_len_s)
    
    for i, s in enumerate(input_signal):
        padded_input[i, :s.shape[-1]] = s
        padded_target[i, :s.shape[-1]] = target_signal[i]

    return padded_input, padded_target


def collate_fn(batch):
    
    padded_input, padded_target = pad_sequence(batch)
        
    padded_input = padded_input.reshape(-1, padded_input.shape[-1])
    padded_target = padded_target.reshape(-1, padded_input.shape[-1])

    return padded_input, padded_target

# %%
test_dataloader = DataLoader(dataset, batch_size=1, shuffle=False, drop_last=False, collate_fn=collate_fn)

# %%
import time

def check_stream_inference(model, loader, window_size = 1 * SR // 4, device="cpu"):
    model.eval()

    result_nisqa_full = []
    result_rtf_full = []
    result_nisqa_chunk = []
    result_rtf_chunk = []
    with torch.no_grad():
        for signal, target in tqdm(loader):
            signal = signal.to(device)
            target = target.to(device)
            window = vorbis_window(N_FFTS).to(device)
    
            start_time = time.time()
            spec = torch.stft(
                signal,
                n_fft=N_FFTS,
                hop_length=HOP_LENGTH,
                # onesided=True,
                win_length=N_FFTS,
                window=window,
                return_complex=True,
                normalized=True,
                center=True
            ) 

            # spec = use_pcs(spec, N_FFTS)
            
            output, _ = model_eval_old(model, spec, configs, device, hid_size=HID_SIZE)

            # output = inv_pcs(output.abs(), output.angle())

            window = vorbis_window(N_FFTS).to(device)
            output = torch.istft(output, n_fft=N_FFTS, hop_length=HOP_LENGTH, win_length=N_FFTS,
                                   window=window,
                                   # onesided=True,
                                   return_complex=False,
                                   normalized=True,
                                   center=True)
            
            end_time = time.time()
            
            result_rtf_full.append((signal.shape[-1] / SR) / (end_time - start_time))
            nisqa_score, _, _ = process(output.detach().cpu(), SR, nisqa, h0_nisqa, c0_nisqa, nisqa_args)
            result_nisqa_full.append(nisqa_score)

            for j in range(0, signal.shape[-1], window_size):
                chunk = signal[..., j:j+window_size]
                
                if chunk.shape[-1] < 10_000:
                    continue

                start_time = time.time()
                spec = torch.stft(
                    chunk,
                    n_fft=N_FFTS,
                    hop_length=HOP_LENGTH,
                    # onesided=True,
                    win_length=N_FFTS,
                    window=window,
                    return_complex=True,
                    normalized=True,
                    center=True
                )

                output, _ = model_eval_old(model, spec, configs, device, hid_size=HID_SIZE)

                window = vorbis_window(N_FFTS).to(device)
                output = torch.istft(output, n_fft=N_FFTS, hop_length=HOP_LENGTH, win_length=N_FFTS,
                                    window=window,
                                    # onesided=True,
                                    return_complex=False,
                                    normalized=True,
                                    center=True)
                
                end_time = time.time()


                result_rtf_chunk.append((chunk.shape[-1] / SR) / (end_time - start_time))
                # print(output.shape)
                nisqa_score, _, _ = process(output.detach().cpu(), SR, nisqa, h0_nisqa, c0_nisqa, nisqa_args)

                result_nisqa_chunk.append(nisqa_score)
                

    print(f"Mean nisqa for full audio: ", torch.stack(result_nisqa_full).mean(dim=0))
    print(f"Mean rtf for full audio: ", torch.tensor(result_rtf_full).mean(dim=0), 1 / torch.tensor(result_rtf_full).mean(dim=0))
    print("---" * 10)
    print("Mean nisqa for \"stream\" audio: ", torch.stack(result_nisqa_chunk).mean(dim=0))
    print("Mean rtf for \"stream\" audio: ", torch.tensor(result_rtf_chunk).mean(dim=-1), 1 / torch.tensor(result_rtf_chunk).mean(dim=-1))

    return result_nisqa_full, result_rtf_full, result_nisqa_chunk, result_rtf_chunk

# %%
# _ = check_stream_inference(fspen, test_dataloader, device="cpu")

# %%
from torchmetrics.audio.pesq import PerceptualEvaluationSpeechQuality
from torch_stoi import NegSTOILoss

srmr = SpeechReverberationModulationEnergyRatio(fs=16_000, norm=False)
pesq = PerceptualEvaluationSpeechQuality(fs=16_000, mode="wb").to("cuda")
pesq_loss = PesqLoss(factor=0.5, sample_rate=48_000).to("cuda")
stoi = NegSTOILoss(SR, use_vad=False, do_resample=False).to("cuda")
dnsmos = DeepNoiseSuppressionMeanOpinionScore(16_000, False, device=DEVICE)

# %%
from torchaudio.transforms import Resample
from thop import profile


def get_metrics(model, loader, device="cpu"):
    model.eval()
    
    model = model.to(device)
    
    nisqa_scores = []
    pesq_scores = []
    pesq_loss_scores = []
    stoi_scores = []
    srmr_scores = []
    dnsmos_scores = []
    macs_list = []
    with torch.no_grad():
        for signal, target in tqdm(loader):
            signal = signal.to(device)
            target = target.to(device)
            window = vorbis_window(N_FFTS).to(device)
    
            spec = torch.stft(
                signal,
                n_fft=N_FFTS,
                hop_length=HOP_LENGTH,
                # onesided=True,
                win_length=N_FFTS,
                window=window,
                return_complex=True,
                normalized=True,
                center=True
            )

            # spec = use_pcs(spec, N_FFTS)
            # print(spec.device)
            output, _ = model_eval_old(model, spec, configs, device, hid_size=32)

            abs_s = spec.abs()
            input_s_ = torch.permute(torch.view_as_real(spec), dims=(0, 2, 3, 1))
            batch, frames, channels, frequency = input_s_.shape
            abs_s = torch.permute(abs_s, dims=(0, 2, 1))
            abs_s = torch.reshape(abs_s, shape=(batch, frames, 1, frequency))
            h0 = [[torch.zeros(configs.dual_path_extension["parameters"]["num_layers"], batch * configs.num_bands_out, configs.dual_path_extension["parameters"]["inter_hidden_size"]) for _ in range(8)] for _ in range(configs.dual_path_extension["num_modules"])]

            start = time.time()
            macs, _ = profile(model.cpu(), inputs=(input_s_.cpu(), abs_s.cpu(), h0), verbose=False)
            end = time.time()
            macs_list.append(macs / (end - start))

            model = model.to(device)

            # output = inv_pcs(output.abs(), output.angle())

            window = vorbis_window(N_FFTS).to(device)
            output = torch.istft(output, n_fft=N_FFTS, hop_length=HOP_LENGTH, win_length=N_FFTS,
                                   window=window,
                                   # onesided=True,
                                   return_complex=False,
                                   normalized=True,
                                   center=True)
            
            # output = output / (output.abs().max() / signal.abs().max())
            
            min_l = min(output.shape[-1], signal.shape[-1])
            output = output[..., :min_l]
            target = target[..., :min_l]

            nisqa_score, _, _ = process(output.detach().cpu(), SR, nisqa, h0_nisqa, c0_nisqa, nisqa_args)
            stoi_score = stoi(output[..., :min_l], target[..., :min_l])

            pesq_loss_score = pesq_loss.mos(target, output)
            
            resampler = Resample(SR, 16_000)
            output = resampler(output.cpu()).cuda()
            target = resampler(target.cpu()).cuda()
            min_l = min(output.shape[-1], target.shape[-1])

            srmr_score = srmr(output.detach().cpu())
            dnsmos_score = dnsmos(output.detach())

            try:
                pesq_score = pesq(output[..., :min_l], target[..., :min_l])
            except Exception as e:
                # print(min_l)
                # out_wave_ = output.reshape(-1)
                # target_ = target.reshape(-1)
                # write('exception_out.wav', SR, out_wave_.cpu().detach().numpy())
                # write('exception_in.wav', SR, target_.cpu().detach().numpy())
                continue

            nisqa_scores.append(nisqa_score[0])
            srmr_scores.append(srmr_score)
            stoi_scores.append(stoi_score.cpu())
            pesq_scores.append(pesq_score.cpu())
            pesq_loss_scores.append(pesq_loss_score.cpu())
            dnsmos_scores.append(dnsmos_score.cpu())

    result = {"nisqa": nisqa_scores, "stoi": stoi_scores, "srmr": srmr_scores, "pesq": pesq_scores, "pesq_loss": pesq_loss_scores, "dnsmos": dnsmos_scores, "macs": macs_list}
        
    return result

# %%
metrics = get_metrics(fspen, test_dataloader, device="cuda")
# Out:
# 100%|██████████| 824/824 [19:31<00:00,  1.42s/it]

# %%
print("NISQA:", torch.vstack(metrics["nisqa"]).mean(dim=0))
print("PESQ:", torch.vstack(metrics["pesq"]).mean(dim=0))
print("PESQ Loss:", torch.vstack(metrics["pesq_loss"]).mean(dim=0))
print("SRMR:", torch.vstack(metrics["srmr"]).mean(dim=0))
print("STOI:", -torch.vstack(metrics["stoi"]).mean(dim=0))
print("DNSMOS:", torch.vstack(metrics["dnsmos"]).mean(dim=0))
print("MACs:", sum(metrics["macs"]) / len(metrics["macs"]))
# Out:
# NISQA: tensor([3.739, 3.834, 3.766, 3.846, 3.909])
# PESQ: tensor([2.326])
# PESQ Loss: tensor([2.261], dtype=torch.float64)
# SRMR: tensor([9.874])
# STOI: tensor([0.885])
# DNSMOS: tensor([3.181, 3.027, 3.792, 2.705], dtype=torch.float64)
# MACs: 6366035245.739882

# %% [markdown]
# NISQA: tensor([3.869, 4.178, 3.810, 3.892, 3.940])
# PESQ: tensor([2.394])
# SRMR: tensor([9.850])
# STOI: tensor([0.891])
# DNSMOS: tensor([3.243, 3.077, 3.919, 2.795], dtype=torch.float64)
# MACs: 1109564823.70259

# %% [markdown]
# NISQA: tensor([3.869, 4.178, 3.810, 3.892, 3.940])
# PESQ: tensor([2.394])
# SRMR: tensor([9.850])
# STOI: tensor([0.891])
# DNSMOS: tensor([3.243, 3.077, 3.919, 2.795], dtype=torch.float64)
# MACs: 1109564823.70259

# %%
fspen
# Out:
# FullSubPathExtensionTRA_ver2(
#   (full_band_encoder): TRAFullBandEncoder(
#     (full_band_encoder): ModuleList(
#       (0): FullBandEncoderBlock(
#         (conv): Conv1d(2, 4, kernel_size=(6,), stride=(2,), padding=(2,))
#         (norm): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ELU(alpha=1.0)
#       )
#       (1): FullBandEncoderBlock(
#         (conv): Conv1d(4, 16, kernel_size=(8,), stride=(2,), padding=(3,))
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ELU(alpha=1.0)
#       )
#       (2): FullBandEncoderBlock(
#         (conv): Conv1d(16, 32, kernel_size=(6,), stride=(2,), padding=(2,))
#         (norm): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ELU(alpha=1.0)
#       )
#     )
#     (global_features): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#     (tra_conv1): TRAEncoderBlock(
#       (conv1): Conv1d(16, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): Conv1d(48, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv3): Conv1d(48, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (norm1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate1): ELU(alpha=1.0)
#       (activate2): ELU(alpha=1.0)
#       (activate3): ELU(alpha=1.0)
#       (tra): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#     (tra_conv2): TRAEncoderBlock(
#       (conv1): Conv1d(16, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): Conv1d(48, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv3): Conv1d(48, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (norm1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate1): ELU(alpha=1.0)
#       (activate2): ELU(alpha=1.0)
#       (activate3): ELU(alpha=1.0)
#       (tra): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#   )
#   (sub_band_encoder): TRASubBandEncoder(
#     (sub_band_encoders): ModuleList(
#       (0-1): 2 x SubBandEncoderBlock(
#         (conv): Conv1d(1, 32, kernel_size=(5,), stride=(3,), padding=(1,))
#         (activate): GELU(approximate='none')
#       )
#       (2-3): 2 x SubBandEncoderBlock(
#         (conv): Conv1d(1, 32, kernel_size=(13,), stride=(6,))
#         (activate): GELU(approximate='none')
#       )
#       (4-6): 3 x SubBandEncoderBlock(
#         (conv): Conv1d(1, 32, kernel_size=(16,), stride=(9,))
#         (activate): GELU(approximate='none')
#       )
#       (7): SubBandEncoderBlock(
#         (conv): Conv1d(1, 32, kernel_size=(20,), stride=(7,))
#         (activate): GELU(approximate='none')
#       )
#     )
#     (tra1): TRAEncoderBlock(
#       (conv1): Conv1d(16, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): Conv1d(48, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv3): Conv1d(48, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (norm1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate1): ELU(alpha=1.0)
#       (activate2): ELU(alpha=1.0)
#       (activate3): ELU(alpha=1.0)
#       (tra): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#     (tra2): TRAEncoderBlock(
#       (conv1): Conv1d(16, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): Conv1d(48, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv3): Conv1d(48, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (norm1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate1): ELU(alpha=1.0)
#       (activate2): ELU(alpha=1.0)
#       (activate3): ELU(alpha=1.0)
#       (tra): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#   )
#   (feature_merge_layer): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Conv1d(32, 16, kernel_size=(1,), stride=(1,))
#   )
#   (dual_path_extension_rnn_list): ModuleList(
#     (0-2): 3 x DualPathExtensionRNNTRA(
#       (intra_chunk_rnn): GRU(16, 16, batch_first=True, bidirectional=True)
#       (intra_chunk_fc): Linear(in_features=32, out_features=16, bias=True)
#       (intra_chunk_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (inter_chunk_rnn): GroupRNN(
#         (rnn_list): ModuleList(
#           (0-7): 8 x GRU(16, 16, batch_first=True)
#         )
#       )
#       (inter_chunk_fc): Linear(in_features=128, out_features=16, bias=True)
#       (tra1): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#       (tra2): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#   )
#   (feature_split_layer): Sequential(
#     (0): Conv1d(16, 32, kernel_size=(1,), stride=(1,))
#     (1): Linear(in_features=64, out_features=128, bias=True)
#     (2): ELU(alpha=1.0)
#   )
#   (full_band_decoder): TRAFullBandDecoder(
#     (full_band_decoders): ModuleList(
#       (0): FullBandDecoderBlock(
#         (conv): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#         (convT): ConvTranspose1d(32, 16, kernel_size=(6,), stride=(2,), padding=(2,))
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ELU(alpha=1.0)
#       )
#       (1): FullBandDecoderBlock(
#         (conv): Conv1d(32, 16, kernel_size=(1,), stride=(1,))
#         (convT): ConvTranspose1d(16, 4, kernel_size=(8,), stride=(2,), padding=(3,))
#         (norm): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ELU(alpha=1.0)
#       )
#       (2): FullBandDecoderBlock(
#         (conv): Conv1d(8, 4, kernel_size=(1,), stride=(1,))
#         (convT): ConvTranspose1d(4, 2, kernel_size=(6,), stride=(2,), padding=(2,))
#         (norm): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): Sigmoid()
#         (act2): Tanh()
#       )
#     )
#     (tra1): TRAEncoderBlock(
#       (conv1): ConvTranspose1d(16, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): ConvTranspose1d(48, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv3): ConvTranspose1d(48, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (norm1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate1): ELU(alpha=1.0)
#       (activate2): ELU(alpha=1.0)
#       (activate3): ELU(alpha=1.0)
#       (tra): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#     (tra2): TRAEncoderBlock(
#       (conv1): ConvTranspose1d(16, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): ConvTranspose1d(48, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv3): ConvTranspose1d(48, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (norm1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate1): ELU(alpha=1.0)
#       (activate2): ELU(alpha=1.0)
#       (activate3): ELU(alpha=1.0)
#       (tra): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#   )
#   (sub_band_decoder): TRASubBandDecoder(
#     (sub_band_decoders): ModuleList(
#       (0-1): 2 x SubBandDecoderBlock(
#         (fc): Linear(in_features=64, out_features=3, bias=True)
#         (activate): GELU(approximate='none')
#       )
#       (2-3): 2 x SubBandDecoderBlock(
#         (fc): Linear(in_features=64, out_features=8, bias=True)
#         (activate): GELU(approximate='none')
#       )
#       (4-5): 2 x SubBandDecoderBlock(
#         (fc): Linear(in_features=64, out_features=11, bias=True)
#         (activate): GELU(approximate='none')
#       )
#       (6): SubBandDecoderBlock(
#         (fc): Linear(in_features=64, out_features=10, bias=True)
#         (activate): GELU(approximate='none')
#       )
#       (7): SubBandDecoderBlock(
#         (fc): Linear(in_features=64, out_features=8, bias=True)
#         (activate): Sigmoid()
#       )
#     )
#     (tra1): TRAEncoderBlock(
#       (conv1): ConvTranspose1d(16, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): ConvTranspose1d(48, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv3): ConvTranspose1d(48, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (norm1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate1): ELU(alpha=1.0)
#       (activate2): ELU(alpha=1.0)
#       (activate3): ELU(alpha=1.0)
#       (tra): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#     (tra2): TRAEncoderBlock(
#       (conv1): ConvTranspose1d(16, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): ConvTranspose1d(48, 48, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv3): ConvTranspose1d(48, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (norm1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate1): ELU(alpha=1.0)
#       (activate2): ELU(alpha=1.0)
#       (activate3): ELU(alpha=1.0)
#       (tra): TRA(
#         (att_gru): GRU(16, 32, batch_first=True)
#         (att_fc): Linear(in_features=32, out_features=16, bias=True)
#         (att_act): Sigmoid()
#       )
#     )
#   )
#   (mask_padding): ConstantPad2d(padding=(1, 0, 0, 0), value=0.0)
# )

# %%
input_sig, gt, gt_noise, gt_rir = dataset[0]

# %%
16_000 * (0.325 + 0.1625)
# Out:
# 7800.000000000001

# %%
from thop import profile
import time

window = vorbis_window(N_FFTS)

input_spec = torch.stft(
            input_sig[..., :16_000],
            n_fft=N_FFTS,
            hop_length=HOP_LENGTH,
            # onesided=True,
            win_length=N_FFTS,
            window=window,
            return_complex=True,
            normalized=True,
            center=True
        )

input_spec = input_spec.to("cpu")

abs_spectrum = input_spec.abs()
input_spec_ = torch.permute(torch.view_as_real(input_spec), dims=(0, 2, 3, 1))
batch, frames, channels, frequency = input_spec_.shape
abs_spectrum = torch.permute(abs_spectrum, dims=(0, 2, 1))
abs_spectrum = torch.reshape(abs_spectrum, shape=(batch, frames, 1, frequency))
h0 = [[torch.zeros(configs.dual_path_extension["parameters"]["num_layers"], batch * configs.num_bands_out, configs.dual_path_extension["parameters"]["inter_hidden_size"], device=input_spec.device) for _ in range(8)] for _ in range(configs.dual_path_extension["num_modules"])]

# output, hid_out = fspen(input_spec_, abs_spectrum, h0)
print(input_spec_.shape)

input_spec_ = torch.ones(1, 1, 2, 513)
abs_spectrum = torch.ones(1, 1, 1, 513)

fspen.eval()

start = time.time()
macs, params = profile(fspen.cpu(), inputs=(input_spec_, abs_spectrum, h0))
end = time.time()
# Out:
# torch.Size([1, 32, 2, 513])
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv1d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm1d'>.
# [INFO] Register count_gru() for <class 'torch.nn.modules.rnn.GRU'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.ConvTranspose1d'>.

# %%
print("MACs: ", macs)
print("Params: ", params)
# Out:
# MACs:  11839936.0
# Params:  262720.0

# %%
print("MACs: ", macs / (end - start))
print("Params: ", params)
# Out:
# MACs:  41707784.280258544
# Params:  262720.0

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = fspen.cpu()
        
    def forward(self, image):
        batch, frames, channels, frequency = image.shape
        h0 = [[torch.zeros(configs.dual_path_extension["parameters"]["num_layers"], 1 * configs.num_bands_out, configs.dual_path_extension["parameters"]["inter_hidden_size"]) for _ in range(8)] for _ in range(configs.dual_path_extension["num_modules"])]
        abs_s = image[..., 0, :]
        abs_s = torch.reshape(abs_s, shape=(batch, frames, 1, frequency))
        return fspen(image, abs_s, h0)

# %%
from ptflops import get_model_complexity_info

my_model = MyModel()

with torch.no_grad():
    input_spec_ = torch.ones(1, 1, 2, 257)
    abs_spectrum = torch.ones(1, 1, 1, 257)

    macs, params = get_model_complexity_info(
        my_model,
        (32, 2, 257),   # размер входа: C, H, W
        as_strings=True, # вернуть красиво отформатированные строки
        print_per_layer_stat=True,
        verbose=True
    )

print("MACs:", macs)
print("Params:", params)
# Out:
# Warning: module FullBandEncoderBlock is treated as a zero-op.
# Warning: module Sigmoid is treated as a zero-op.
# Warning: module TRA is treated as a zero-op.
# Warning: module TRAEncoderBlock is treated as a zero-op.
# Warning: module TRAFullBandEncoder is treated as a zero-op.
# Warning: module SubBandEncoderBlock is treated as a zero-op.
# Warning: module TRASubBandEncoder is treated as a zero-op.
# Warning: module GroupRNN is treated as a zero-op.
# Warning: module DualPathExtensionRNNTRA is treated as a zero-op.
# Warning: module FullBandDecoderBlock is treated as a zero-op.
# Warning: module Tanh is treated as a zero-op.
# Warning: module TRAFullBandDecoder is treated as a zero-op.
# Warning: module SubBandDecoderBlock is treated as a zero-op.
# Warning: module TRASubBandDecoder is treated as a zero-op.
# Warning: module ConstantPad2d is treated as a zero-op.
# Warning: module FullSubPathExtensionTRA_ver2 is treated as a zero-op.
# Warning: module MyModel is treated as a zero-op.
# Conv has NaNs:  True
# After norm:  True
# After activation:  True
# Flops estimation was not finished successfully because of the following exception:
# <class 'AssertionError'>: fullband enc conv_0 out has NaNs
# MACs: None
# Params: None
# Traceback (most recent call last):
#   File "/home/zakhar/miniconda3/envs/ems_dereverb/lib/python3.10/site-packages/ptflops/pytorch_engine.py", line 68, in get_flops_pytorch
#     _ = flops_model(batch)
#   File "/home/zakhar/miniconda3/envs/ems_dereverb/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/zakhar/miniconda3/envs/ems_dereverb/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1561, in _call_impl
#     result = forward_call(*args, **kwargs)
#   File "/tmp/ipykernel_86356/4146406547.py", line 11, in forward
#     return fspen(image, abs_s, h0)
#   File "/home/zakhar/miniconda3/envs/ems_dereverb/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/zakhar/miniconda3/envs/ems_dereverb/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/zakhar/ems_dereverb/models/fspen.py", line 825, in forward
#     full_band_encode_outs, global_feature = self.full_band_encoder(complex_spectrum, batch)
#   File "/home/zakhar/miniconda3/envs/ems_dereverb/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/zakhar/miniconda3/envs/ems_dereverb/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/zakhar/ems_dereverb/models/fspen.py", line 72, in forward
#     assert torch.isnan(complex_spectrum).any().item() is False, f"fullband enc conv_{i} out has NaNs"
# AssertionError: fullband enc conv_0 out has NaNs

# %%
from src.utils import model_num_params

_, _ = model_num_params(fspen)
# Out:
# full_band_encoder.full_band_encoder.0.conv.weight ~  48        params ~ grad: True
# full_band_encoder.full_band_encoder.0.conv.bias ~  4         params ~ grad: True
# full_band_encoder.full_band_encoder.0.norm.weight ~  4         params ~ grad: True
# full_band_encoder.full_band_encoder.0.norm.bias ~  4         params ~ grad: True
# full_band_encoder.full_band_encoder.1.conv.weight ~  512       params ~ grad: True
# full_band_encoder.full_band_encoder.1.conv.bias ~  16        params ~ grad: True
# full_band_encoder.full_band_encoder.1.norm.weight ~  16        params ~ grad: True
# full_band_encoder.full_band_encoder.1.norm.bias ~  16        params ~ grad: True
# full_band_encoder.full_band_encoder.2.conv.weight ~  3.072     params ~ grad: True
# full_band_encoder.full_band_encoder.2.conv.bias ~  32        params ~ grad: True
# full_band_encoder.full_band_encoder.2.norm.weight ~  32        params ~ grad: True
# full_band_encoder.full_band_encoder.2.norm.bias ~  32        params ~ grad: True
# full_band_encoder.global_features.weight   ~  1.024     params ~ grad: True
# full_band_encoder.global_features.bias     ~  32        params ~ grad: True
# full_band_encoder.tra_conv1.conv1.weight   ~  2.304     params ~ grad: True
# full_band_encoder.tra_conv1.conv1.bias     ~  48        params ~ grad: True
# full_band_encoder.tra_conv1.conv2.weight   ~  6.912     params ~ grad: True
# full_band_encoder.tra_conv1.conv2.bias     ~  48        params ~ grad: True
# full_band_encoder.tra_conv1.conv3.weight   ~  2.304     params ~ grad: True
# full_band_encoder.tra_conv1.conv3.bias     ~  16        params ~ grad: True
# full_band_encoder.tra_conv1.norm1.weight   ~  48        params ~ grad: True
# full_band_encoder.tra_conv1.norm1.bias     ~  48        params ~ grad: True
# full_band_encoder.tra_conv1.norm2.weight   ~  48        params ~ grad: True
# full_band_encoder.tra_conv1.norm2.bias     ~  48        params ~ grad: True
# full_band_encoder.tra_conv1.norm3.weight   ~  16        params ~ grad: True
# full_band_encoder.tra_conv1.norm3.bias     ~  16        params ~ grad: True
# full_band_encoder.tra_conv1.tra.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# full_band_encoder.tra_conv1.tra.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# full_band_encoder.tra_conv1.tra.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# full_band_encoder.tra_conv1.tra.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# full_band_encoder.tra_conv1.tra.att_fc.weight ~  512       params ~ grad: True
# full_band_encoder.tra_conv1.tra.att_fc.bias ~  16        params ~ grad: True
# full_band_encoder.tra_conv2.conv1.weight   ~  2.304     params ~ grad: True
# full_band_encoder.tra_conv2.conv1.bias     ~  48        params ~ grad: True
# full_band_encoder.tra_conv2.conv2.weight   ~  6.912     params ~ grad: True
# full_band_encoder.tra_conv2.conv2.bias     ~  48        params ~ grad: True
# full_band_encoder.tra_conv2.conv3.weight   ~  2.304     params ~ grad: True
# full_band_encoder.tra_conv2.conv3.bias     ~  16        params ~ grad: True
# full_band_encoder.tra_conv2.norm1.weight   ~  48        params ~ grad: True
# full_band_encoder.tra_conv2.norm1.bias     ~  48        params ~ grad: True
# full_band_encoder.tra_conv2.norm2.weight   ~  48        params ~ grad: True
# full_band_encoder.tra_conv2.norm2.bias     ~  48        params ~ grad: True
# full_band_encoder.tra_conv2.norm3.weight   ~  16        params ~ grad: True
# full_band_encoder.tra_conv2.norm3.bias     ~  16        params ~ grad: True
# full_band_encoder.tra_conv2.tra.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# full_band_encoder.tra_conv2.tra.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# full_band_encoder.tra_conv2.tra.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# full_band_encoder.tra_conv2.tra.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# full_band_encoder.tra_conv2.tra.att_fc.weight ~  512       params ~ grad: True
# full_band_encoder.tra_conv2.tra.att_fc.bias ~  16        params ~ grad: True
# sub_band_encoder.sub_band_encoders.0.conv.weight ~  160       params ~ grad: True
# sub_band_encoder.sub_band_encoders.0.conv.bias ~  32        params ~ grad: True
# sub_band_encoder.sub_band_encoders.1.conv.weight ~  160       params ~ grad: True
# sub_band_encoder.sub_band_encoders.1.conv.bias ~  32        params ~ grad: True
# sub_band_encoder.sub_band_encoders.2.conv.weight ~  416       params ~ grad: True
# sub_band_encoder.sub_band_encoders.2.conv.bias ~  32        params ~ grad: True
# sub_band_encoder.sub_band_encoders.3.conv.weight ~  416       params ~ grad: True
# sub_band_encoder.sub_band_encoders.3.conv.bias ~  32        params ~ grad: True
# sub_band_encoder.sub_band_encoders.4.conv.weight ~  512       params ~ grad: True
# sub_band_encoder.sub_band_encoders.4.conv.bias ~  32        params ~ grad: True
# sub_band_encoder.sub_band_encoders.5.conv.weight ~  512       params ~ grad: True
# sub_band_encoder.sub_band_encoders.5.conv.bias ~  32        params ~ grad: True
# sub_band_encoder.sub_band_encoders.6.conv.weight ~  512       params ~ grad: True
# sub_band_encoder.sub_band_encoders.6.conv.bias ~  32        params ~ grad: True
# sub_band_encoder.sub_band_encoders.7.conv.weight ~  640       params ~ grad: True
# sub_band_encoder.sub_band_encoders.7.conv.bias ~  32        params ~ grad: True
# sub_band_encoder.tra1.conv1.weight         ~  2.304     params ~ grad: True
# sub_band_encoder.tra1.conv1.bias           ~  48        params ~ grad: True
# sub_band_encoder.tra1.conv2.weight         ~  6.912     params ~ grad: True
# sub_band_encoder.tra1.conv2.bias           ~  48        params ~ grad: True
# sub_band_encoder.tra1.conv3.weight         ~  2.304     params ~ grad: True
# sub_band_encoder.tra1.conv3.bias           ~  16        params ~ grad: True
# sub_band_encoder.tra1.norm1.weight         ~  48        params ~ grad: True
# sub_band_encoder.tra1.norm1.bias           ~  48        params ~ grad: True
# sub_band_encoder.tra1.norm2.weight         ~  48        params ~ grad: True
# sub_band_encoder.tra1.norm2.bias           ~  48        params ~ grad: True
# sub_band_encoder.tra1.norm3.weight         ~  16        params ~ grad: True
# sub_band_encoder.tra1.norm3.bias           ~  16        params ~ grad: True
# sub_band_encoder.tra1.tra.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# sub_band_encoder.tra1.tra.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# sub_band_encoder.tra1.tra.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# sub_band_encoder.tra1.tra.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# sub_band_encoder.tra1.tra.att_fc.weight    ~  512       params ~ grad: True
# sub_band_encoder.tra1.tra.att_fc.bias      ~  16        params ~ grad: True
# sub_band_encoder.tra2.conv1.weight         ~  2.304     params ~ grad: True
# sub_band_encoder.tra2.conv1.bias           ~  48        params ~ grad: True
# sub_band_encoder.tra2.conv2.weight         ~  6.912     params ~ grad: True
# sub_band_encoder.tra2.conv2.bias           ~  48        params ~ grad: True
# sub_band_encoder.tra2.conv3.weight         ~  2.304     params ~ grad: True
# sub_band_encoder.tra2.conv3.bias           ~  16        params ~ grad: True
# sub_band_encoder.tra2.norm1.weight         ~  48        params ~ grad: True
# sub_band_encoder.tra2.norm1.bias           ~  48        params ~ grad: True
# sub_band_encoder.tra2.norm2.weight         ~  48        params ~ grad: True
# sub_band_encoder.tra2.norm2.bias           ~  48        params ~ grad: True
# sub_band_encoder.tra2.norm3.weight         ~  16        params ~ grad: True
# sub_band_encoder.tra2.norm3.bias           ~  16        params ~ grad: True
# sub_band_encoder.tra2.tra.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# sub_band_encoder.tra2.tra.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# sub_band_encoder.tra2.tra.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# sub_band_encoder.tra2.tra.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# sub_band_encoder.tra2.tra.att_fc.weight    ~  512       params ~ grad: True
# sub_band_encoder.tra2.tra.att_fc.bias      ~  16        params ~ grad: True
# feature_merge_layer.0.weight               ~  8.192     params ~ grad: True
# feature_merge_layer.0.bias                 ~  64        params ~ grad: True
# feature_merge_layer.2.weight               ~  512       params ~ grad: True
# feature_merge_layer.2.bias                 ~  16        params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_rnn.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_rnn.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_rnn.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_rnn.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_rnn.weight_ih_l0_reverse ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_rnn.weight_hh_l0_reverse ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_rnn.bias_ih_l0_reverse ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_rnn.bias_hh_l0_reverse ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_norm.weight ~  16        params ~ grad: True
# dual_path_extension_rnn_list.0.intra_chunk_norm.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.0.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.0.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.0.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.0.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.1.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.1.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.1.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.1.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.2.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.2.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.2.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.2.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.3.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.3.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.3.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.3.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.4.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.4.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.4.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.4.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.5.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.5.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.5.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.5.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.6.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.6.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.6.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.6.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.7.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.7.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.7.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_rnn.rnn_list.7.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_fc.weight ~  2.048     params ~ grad: True
# dual_path_extension_rnn_list.0.inter_chunk_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.0.tra1.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# dual_path_extension_rnn_list.0.tra1.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# dual_path_extension_rnn_list.0.tra1.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.0.tra1.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.0.tra1.att_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.0.tra1.att_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.0.tra2.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# dual_path_extension_rnn_list.0.tra2.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# dual_path_extension_rnn_list.0.tra2.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.0.tra2.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.0.tra2.att_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.0.tra2.att_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_rnn.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_rnn.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_rnn.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_rnn.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_rnn.weight_ih_l0_reverse ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_rnn.weight_hh_l0_reverse ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_rnn.bias_ih_l0_reverse ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_rnn.bias_hh_l0_reverse ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_norm.weight ~  16        params ~ grad: True
# dual_path_extension_rnn_list.1.intra_chunk_norm.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.0.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.0.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.0.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.0.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.1.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.1.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.1.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.1.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.2.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.2.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.2.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.2.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.3.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.3.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.3.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.3.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.4.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.4.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.4.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.4.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.5.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.5.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.5.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.5.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.6.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.6.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.6.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.6.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.7.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.7.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.7.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_rnn.rnn_list.7.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_fc.weight ~  2.048     params ~ grad: True
# dual_path_extension_rnn_list.1.inter_chunk_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.1.tra1.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# dual_path_extension_rnn_list.1.tra1.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# dual_path_extension_rnn_list.1.tra1.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.1.tra1.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.1.tra1.att_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.1.tra1.att_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.1.tra2.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# dual_path_extension_rnn_list.1.tra2.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# dual_path_extension_rnn_list.1.tra2.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.1.tra2.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.1.tra2.att_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.1.tra2.att_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_rnn.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_rnn.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_rnn.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_rnn.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_rnn.weight_ih_l0_reverse ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_rnn.weight_hh_l0_reverse ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_rnn.bias_ih_l0_reverse ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_rnn.bias_hh_l0_reverse ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_norm.weight ~  16        params ~ grad: True
# dual_path_extension_rnn_list.2.intra_chunk_norm.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.0.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.0.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.0.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.0.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.1.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.1.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.1.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.1.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.2.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.2.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.2.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.2.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.3.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.3.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.3.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.3.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.4.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.4.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.4.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.4.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.5.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.5.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.5.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.5.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.6.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.6.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.6.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.6.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.7.weight_ih_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.7.weight_hh_l0 ~  768       params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.7.bias_ih_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_rnn.rnn_list.7.bias_hh_l0 ~  48        params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_fc.weight ~  2.048     params ~ grad: True
# dual_path_extension_rnn_list.2.inter_chunk_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.2.tra1.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# dual_path_extension_rnn_list.2.tra1.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# dual_path_extension_rnn_list.2.tra1.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.2.tra1.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.2.tra1.att_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.2.tra1.att_fc.bias ~  16        params ~ grad: True
# dual_path_extension_rnn_list.2.tra2.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# dual_path_extension_rnn_list.2.tra2.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# dual_path_extension_rnn_list.2.tra2.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.2.tra2.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# dual_path_extension_rnn_list.2.tra2.att_fc.weight ~  512       params ~ grad: True
# dual_path_extension_rnn_list.2.tra2.att_fc.bias ~  16        params ~ grad: True
# feature_split_layer.0.weight               ~  512       params ~ grad: True
# feature_split_layer.0.bias                 ~  32        params ~ grad: True
# feature_split_layer.1.weight               ~  8.192     params ~ grad: True
# feature_split_layer.1.bias                 ~  128       params ~ grad: True
# full_band_decoder.full_band_decoders.0.conv.weight ~  2.048     params ~ grad: True
# full_band_decoder.full_band_decoders.0.conv.bias ~  32        params ~ grad: True
# full_band_decoder.full_band_decoders.0.convT.weight ~  3.072     params ~ grad: True
# full_band_decoder.full_band_decoders.0.convT.bias ~  16        params ~ grad: True
# full_band_decoder.full_band_decoders.0.norm.weight ~  16        params ~ grad: True
# full_band_decoder.full_band_decoders.0.norm.bias ~  16        params ~ grad: True
# full_band_decoder.full_band_decoders.1.conv.weight ~  512       params ~ grad: True
# full_band_decoder.full_band_decoders.1.conv.bias ~  16        params ~ grad: True
# full_band_decoder.full_band_decoders.1.convT.weight ~  512       params ~ grad: True
# full_band_decoder.full_band_decoders.1.convT.bias ~  4         params ~ grad: True
# full_band_decoder.full_band_decoders.1.norm.weight ~  4         params ~ grad: True
# full_band_decoder.full_band_decoders.1.norm.bias ~  4         params ~ grad: True
# full_band_decoder.full_band_decoders.2.conv.weight ~  32        params ~ grad: True
# full_band_decoder.full_band_decoders.2.conv.bias ~  4         params ~ grad: True
# full_band_decoder.full_band_decoders.2.convT.weight ~  48        params ~ grad: True
# full_band_decoder.full_band_decoders.2.convT.bias ~  2         params ~ grad: True
# full_band_decoder.full_band_decoders.2.norm.weight ~  2         params ~ grad: True
# full_band_decoder.full_band_decoders.2.norm.bias ~  2         params ~ grad: True
# full_band_decoder.tra1.conv1.weight        ~  2.304     params ~ grad: True
# full_band_decoder.tra1.conv1.bias          ~  48        params ~ grad: True
# full_band_decoder.tra1.conv2.weight        ~  6.912     params ~ grad: True
# full_band_decoder.tra1.conv2.bias          ~  48        params ~ grad: True
# full_band_decoder.tra1.conv3.weight        ~  2.304     params ~ grad: True
# full_band_decoder.tra1.conv3.bias          ~  16        params ~ grad: True
# full_band_decoder.tra1.norm1.weight        ~  48        params ~ grad: True
# full_band_decoder.tra1.norm1.bias          ~  48        params ~ grad: True
# full_band_decoder.tra1.norm2.weight        ~  48        params ~ grad: True
# full_band_decoder.tra1.norm2.bias          ~  48        params ~ grad: True
# full_band_decoder.tra1.norm3.weight        ~  16        params ~ grad: True
# full_band_decoder.tra1.norm3.bias          ~  16        params ~ grad: True
# full_band_decoder.tra1.tra.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# full_band_decoder.tra1.tra.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# full_band_decoder.tra1.tra.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# full_band_decoder.tra1.tra.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# full_band_decoder.tra1.tra.att_fc.weight   ~  512       params ~ grad: True
# full_band_decoder.tra1.tra.att_fc.bias     ~  16        params ~ grad: True
# full_band_decoder.tra2.conv1.weight        ~  2.304     params ~ grad: True
# full_band_decoder.tra2.conv1.bias          ~  48        params ~ grad: True
# full_band_decoder.tra2.conv2.weight        ~  6.912     params ~ grad: True
# full_band_decoder.tra2.conv2.bias          ~  48        params ~ grad: True
# full_band_decoder.tra2.conv3.weight        ~  2.304     params ~ grad: True
# full_band_decoder.tra2.conv3.bias          ~  16        params ~ grad: True
# full_band_decoder.tra2.norm1.weight        ~  48        params ~ grad: True
# full_band_decoder.tra2.norm1.bias          ~  48        params ~ grad: True
# full_band_decoder.tra2.norm2.weight        ~  48        params ~ grad: True
# full_band_decoder.tra2.norm2.bias          ~  48        params ~ grad: True
# full_band_decoder.tra2.norm3.weight        ~  16        params ~ grad: True
# full_band_decoder.tra2.norm3.bias          ~  16        params ~ grad: True
# full_band_decoder.tra2.tra.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# full_band_decoder.tra2.tra.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# full_band_decoder.tra2.tra.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# full_band_decoder.tra2.tra.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# full_band_decoder.tra2.tra.att_fc.weight   ~  512       params ~ grad: True
# full_band_decoder.tra2.tra.att_fc.bias     ~  16        params ~ grad: True
# sub_band_decoder.sub_band_decoders.0.fc.weight ~  192       params ~ grad: True
# sub_band_decoder.sub_band_decoders.0.fc.bias ~  3         params ~ grad: True
# sub_band_decoder.sub_band_decoders.1.fc.weight ~  192       params ~ grad: True
# sub_band_decoder.sub_band_decoders.1.fc.bias ~  3         params ~ grad: True
# sub_band_decoder.sub_band_decoders.2.fc.weight ~  512       params ~ grad: True
# sub_band_decoder.sub_band_decoders.2.fc.bias ~  8         params ~ grad: True
# sub_band_decoder.sub_band_decoders.3.fc.weight ~  512       params ~ grad: True
# sub_band_decoder.sub_band_decoders.3.fc.bias ~  8         params ~ grad: True
# sub_band_decoder.sub_band_decoders.4.fc.weight ~  704       params ~ grad: True
# sub_band_decoder.sub_band_decoders.4.fc.bias ~  11        params ~ grad: True
# sub_band_decoder.sub_band_decoders.5.fc.weight ~  704       params ~ grad: True
# sub_band_decoder.sub_band_decoders.5.fc.bias ~  11        params ~ grad: True
# sub_band_decoder.sub_band_decoders.6.fc.weight ~  640       params ~ grad: True
# sub_band_decoder.sub_band_decoders.6.fc.bias ~  10        params ~ grad: True
# sub_band_decoder.sub_band_decoders.7.fc.weight ~  512       params ~ grad: True
# sub_band_decoder.sub_band_decoders.7.fc.bias ~  8         params ~ grad: True
# sub_band_decoder.tra1.conv1.weight         ~  2.304     params ~ grad: True
# sub_band_decoder.tra1.conv1.bias           ~  48        params ~ grad: True
# sub_band_decoder.tra1.conv2.weight         ~  6.912     params ~ grad: True
# sub_band_decoder.tra1.conv2.bias           ~  48        params ~ grad: True
# sub_band_decoder.tra1.conv3.weight         ~  2.304     params ~ grad: True
# sub_band_decoder.tra1.conv3.bias           ~  16        params ~ grad: True
# sub_band_decoder.tra1.norm1.weight         ~  48        params ~ grad: True
# sub_band_decoder.tra1.norm1.bias           ~  48        params ~ grad: True
# sub_band_decoder.tra1.norm2.weight         ~  48        params ~ grad: True
# sub_band_decoder.tra1.norm2.bias           ~  48        params ~ grad: True
# sub_band_decoder.tra1.norm3.weight         ~  16        params ~ grad: True
# sub_band_decoder.tra1.norm3.bias           ~  16        params ~ grad: True
# sub_band_decoder.tra1.tra.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# sub_band_decoder.tra1.tra.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# sub_band_decoder.tra1.tra.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# sub_band_decoder.tra1.tra.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# sub_band_decoder.tra1.tra.att_fc.weight    ~  512       params ~ grad: True
# sub_band_decoder.tra1.tra.att_fc.bias      ~  16        params ~ grad: True
# sub_band_decoder.tra2.conv1.weight         ~  2.304     params ~ grad: True
# sub_band_decoder.tra2.conv1.bias           ~  48        params ~ grad: True
# sub_band_decoder.tra2.conv2.weight         ~  6.912     params ~ grad: True
# sub_band_decoder.tra2.conv2.bias           ~  48        params ~ grad: True
# sub_band_decoder.tra2.conv3.weight         ~  2.304     params ~ grad: True
# sub_band_decoder.tra2.conv3.bias           ~  16        params ~ grad: True
# sub_band_decoder.tra2.norm1.weight         ~  48        params ~ grad: True
# sub_band_decoder.tra2.norm1.bias           ~  48        params ~ grad: True
# sub_band_decoder.tra2.norm2.weight         ~  48        params ~ grad: True
# sub_band_decoder.tra2.norm2.bias           ~  48        params ~ grad: True
# sub_band_decoder.tra2.norm3.weight         ~  16        params ~ grad: True
# sub_band_decoder.tra2.norm3.bias           ~  16        params ~ grad: True
# sub_band_decoder.tra2.tra.att_gru.weight_ih_l0 ~  1.536     params ~ grad: True
# sub_band_decoder.tra2.tra.att_gru.weight_hh_l0 ~  3.072     params ~ grad: True
# sub_band_decoder.tra2.tra.att_gru.bias_ih_l0 ~  96        params ~ grad: True
# sub_band_decoder.tra2.tra.att_gru.bias_hh_l0 ~  96        params ~ grad: True
# sub_band_decoder.tra2.tra.att_fc.weight    ~  512       params ~ grad: True
# sub_band_decoder.tra2.tra.att_fc.bias      ~  16        params ~ grad: True
#
# In total:
#   - 262.720 params
#   - 262.720 learnable params
#
#  . full_band_encoder:
#  .   - 39.212 params
#  .   - 39.212 learnable params
#
#  . sub_band_encoder:
#  .   - 37.952 params
#  .   - 37.952 learnable params
#
#  . feature_merge_layer:
#  .   - 8.784 params
#  .   - 8.784 learnable params
#
#  . dual_path_extension_rnn_list:
#  .   - 88.800 params
#  .   - 88.800 learnable params
#
#  . feature_split_layer:
#  .   - 8.864 params
#  .   - 8.864 learnable params
#
#  . full_band_decoder:
#  .   - 40.710 params
#  .   - 40.710 learnable params
#
#  . sub_band_decoder:
#  .   - 38.398 params
#  .   - 38.398 learnable params
